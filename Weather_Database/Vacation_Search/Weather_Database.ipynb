# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | grindavik
# Processing Record 3 of Set 1 | vitim
# Processing Record 4 of Set 1 | jaisalmer
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | anito
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | ust-maya
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | manokwari
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | narsaq
# Processing Record 15 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | peterhead
# Processing Record 18 of Set 1 | woodward
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | phan thiet
# Processing Record 26 of Set 1 | klaksvik
# Processing Record 27 of Set 1 | mount isa
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | erice
# Processing Record 32 of Set 1 | fort nelson
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | san quintin
# Processing Record 36 of Set 1 | manzanillo
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | san policarpo
# Processing Record 41 of Set 1 | srednekolymsk
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | beirut
# Processing Record 46 of Set 1 | cervo
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | sinnamary
# Processing Record 50 of Set 1 | vardo
# Processing Record 1 of Set 2 | sisimiut
# Processing Record 2 of Set 2 | martapura
# Processing Record 3 of Set 2 | basoko
# Processing Record 4 of Set 2 | te anau
# Processing Record 5 of Set 2 | luorong
# Processing Record 6 of Set 2 | muyezerskiy
# Processing Record 7 of Set 2 | thohoyandou
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | svetlogorsk
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | tigil
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | gobabis
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 2 | hambantota
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | pacific grove
# Processing Record 20 of Set 2 | gat
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | mareeba
# Processing Record 26 of Set 2 | balabac
# Processing Record 27 of Set 2 | rikitea
# Processing Record 28 of Set 2 | shache
# Processing Record 29 of Set 2 | yashkul
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | sinjar
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | buala
# Processing Record 35 of Set 2 | banda aceh
# Processing Record 36 of Set 2 | san jose de guanipa
# Processing Record 37 of Set 2 | daru
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | polunochnoye
# Processing Record 40 of Set 2 | katsuura
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | komsomolskiy
# Processing Record 44 of Set 2 | jieshi
# Processing Record 45 of Set 2 | boissevain
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | fangshan
# Processing Record 49 of Set 2 | tsiroanomandidy
# Processing Record 50 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-georges
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 3 | moorhead
# Processing Record 5 of Set 3 | jizan
# Processing Record 6 of Set 3 | hanzhong
# Processing Record 7 of Set 3 | acapulco
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | zhigansk
# Processing Record 10 of Set 3 | susaki
# Processing Record 11 of Set 3 | dikson
# Processing Record 12 of Set 3 | ninghai
# Processing Record 13 of Set 3 | virden
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | makakilo city
# Processing Record 17 of Set 3 | ridgecrest
# Processing Record 18 of Set 3 | yandoon
# City not found. Skipping...
# Processing Record 19 of Set 3 | camopi
# Processing Record 20 of Set 3 | north bend
# Processing Record 21 of Set 3 | hualmay
# Processing Record 22 of Set 3 | urucurituba
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | labuhan
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | shingu
# Processing Record 28 of Set 3 | corlu
# Processing Record 29 of Set 3 | margate
# Processing Record 30 of Set 3 | new norfolk
# Processing Record 31 of Set 3 | cape coast
# Processing Record 32 of Set 3 | raga
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | nhulunbuy
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | emerald
# Processing Record 40 of Set 3 | kribi
# Processing Record 41 of Set 3 | ixtapa
# Processing Record 42 of Set 3 | miri
# Processing Record 43 of Set 3 | paamiut
# Processing Record 44 of Set 3 | praia
# Processing Record 45 of Set 3 | san cristobal
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | sinjah
# City not found. Skipping...
# Processing Record 48 of Set 3 | ilhabela
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | camacha
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | yakeshi
# Processing Record 3 of Set 4 | saint-francois
# Processing Record 4 of Set 4 | marawi
# Processing Record 5 of Set 4 | cairns
# Processing Record 6 of Set 4 | zaozerne
# Processing Record 7 of Set 4 | kavaratti
# Processing Record 8 of Set 4 | sao joao da barra
# Processing Record 9 of Set 4 | zhangjiakou
# Processing Record 10 of Set 4 | nortelandia
# Processing Record 11 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 4 | parati
# Processing Record 13 of Set 4 | lockhart
# Processing Record 14 of Set 4 | inhambane
# Processing Record 15 of Set 4 | shannon
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | aksarka
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | ulaangom
# Processing Record 20 of Set 4 | senno
# Processing Record 21 of Set 4 | ocos
# Processing Record 22 of Set 4 | yulara
# Processing Record 23 of Set 4 | palmer
# Processing Record 24 of Set 4 | oussouye
# Processing Record 25 of Set 4 | avera
# Processing Record 26 of Set 4 | sicamous
# Processing Record 27 of Set 4 | chokurdakh
# Processing Record 28 of Set 4 | zheshart
# Processing Record 29 of Set 4 | chom bung
# City not found. Skipping...
# Processing Record 30 of Set 4 | naryan-mar
# Processing Record 31 of Set 4 | port-gentil
# Processing Record 32 of Set 4 | owando
# Processing Record 33 of Set 4 | marsa matruh
# Processing Record 34 of Set 4 | yar-sale
# Processing Record 35 of Set 4 | saint-augustin
# Processing Record 36 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 37 of Set 4 | iqaluit
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | shetpe
# Processing Record 40 of Set 4 | pisco
# Processing Record 41 of Set 4 | ostrovnoy
# Processing Record 42 of Set 4 | longyearbyen
# Processing Record 43 of Set 4 | harper
# Processing Record 44 of Set 4 | saint anthony
# Processing Record 45 of Set 4 | tabou
# Processing Record 46 of Set 4 | mehamn
# Processing Record 47 of Set 4 | camana
# Processing Record 48 of Set 4 | monrovia
# Processing Record 49 of Set 4 | vanimo
# Processing Record 50 of Set 4 | lebu
# Processing Record 1 of Set 5 | port hedland
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | bilma
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | kirksville
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | campo grande
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | xuddur
# Processing Record 12 of Set 5 | sansai
# City not found. Skipping...
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | tilichiki
# Processing Record 15 of Set 5 | vila
# Processing Record 16 of Set 5 | cape canaveral
# Processing Record 17 of Set 5 | banikoara
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | katobu
# Processing Record 21 of Set 5 | namie
# Processing Record 22 of Set 5 | indramayu
# Processing Record 23 of Set 5 | aswan
# Processing Record 24 of Set 5 | ituango
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | kommunar
# Processing Record 27 of Set 5 | lewistown
# Processing Record 28 of Set 5 | kirensk
# Processing Record 29 of Set 5 | yeppoon
# Processing Record 30 of Set 5 | thompson
# Processing Record 31 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 5 | rocha
# Processing Record 33 of Set 5 | lidkoping
# Processing Record 34 of Set 5 | listvyanka
# Processing Record 35 of Set 5 | upernavik
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | norman wells
# Processing Record 38 of Set 5 | northam
# Processing Record 39 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | clyde river
# Processing Record 43 of Set 5 | khatanga
# Processing Record 44 of Set 5 | vestmannaeyjar
# Processing Record 45 of Set 5 | wanning
# Processing Record 46 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 5 | touros
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | coihaique
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | kutum
# Processing Record 2 of Set 6 | roros
# Processing Record 3 of Set 6 | torbay
# Processing Record 4 of Set 6 | monki
# Processing Record 5 of Set 6 | kismayo
# Processing Record 6 of Set 6 | tocopilla
# Processing Record 7 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 6 | pushkino
# Processing Record 9 of Set 6 | havoysund
# Processing Record 10 of Set 6 | thinadhoo
# Processing Record 11 of Set 6 | culpeper
# Processing Record 12 of Set 6 | taoudenni
# Processing Record 13 of Set 6 | kolokani
# Processing Record 14 of Set 6 | jiaohe
# Processing Record 15 of Set 6 | fort oglethorpe
# Processing Record 16 of Set 6 | grivenskaya
# Processing Record 17 of Set 6 | tateyama
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | san vicente
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | colares
# Processing Record 22 of Set 6 | takapau
# Processing Record 23 of Set 6 | sheltozero
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | kharovsk
# Processing Record 26 of Set 6 | zhezkazgan
# Processing Record 27 of Set 6 | matagami
# Processing Record 28 of Set 6 | port keats
# Processing Record 29 of Set 6 | jiuquan
# Processing Record 30 of Set 6 | haines junction
# Processing Record 31 of Set 6 | asyut
# Processing Record 32 of Set 6 | hargeysa
# Processing Record 33 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 34 of Set 6 | veraval
# Processing Record 35 of Set 6 | tromso
# Processing Record 36 of Set 6 | pokhara
# Processing Record 37 of Set 6 | sitka
# Processing Record 38 of Set 6 | sampit
# Processing Record 39 of Set 6 | kamalasai
# Processing Record 40 of Set 6 | kytmanovo
# Processing Record 41 of Set 6 | phnum penh
# City not found. Skipping...
# Processing Record 42 of Set 6 | uaua
# Processing Record 43 of Set 6 | port hardy
# Processing Record 44 of Set 6 | strezhevoy
# Processing Record 45 of Set 6 | walvis bay
# Processing Record 46 of Set 6 | port macquarie
# Processing Record 47 of Set 6 | ponta delgada
# Processing Record 48 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 6 | winnemucca
# Processing Record 50 of Set 6 | chirongui
# Processing Record 1 of Set 7 | college
# Processing Record 2 of Set 7 | tuensang
# Processing Record 3 of Set 7 | amalner
# Processing Record 4 of Set 7 | bilibino
# Processing Record 5 of Set 7 | aklavik
# Processing Record 6 of Set 7 | itupiranga
# Processing Record 7 of Set 7 | mitsamiouli
# Processing Record 8 of Set 7 | deputatskiy
# Processing Record 9 of Set 7 | devonport
# Processing Record 10 of Set 7 | seoul
# Processing Record 11 of Set 7 | sur
# Processing Record 12 of Set 7 | boditi
# Processing Record 13 of Set 7 | saldanha
# Processing Record 14 of Set 7 | grinnell
# Processing Record 15 of Set 7 | carnarvon
# Processing Record 16 of Set 7 | coruripe
# Processing Record 17 of Set 7 | kalemie
# Processing Record 18 of Set 7 | san juan
# Processing Record 19 of Set 7 | la cruz
# Processing Record 20 of Set 7 | berekua
# Processing Record 21 of Set 7 | dunedin
# Processing Record 22 of Set 7 | karratha
# Processing Record 23 of Set 7 | isangel
# Processing Record 24 of Set 7 | fort smith
# Processing Record 25 of Set 7 | kodinsk
# Processing Record 26 of Set 7 | pawai
# Processing Record 27 of Set 7 | birao
# Processing Record 28 of Set 7 | beringovskiy
# Processing Record 29 of Set 7 | ous
# Processing Record 30 of Set 7 | butaritari
# Processing Record 31 of Set 7 | bukama
# Processing Record 32 of Set 7 | yumen
# Processing Record 33 of Set 7 | koboldo
# City not found. Skipping...
# Processing Record 34 of Set 7 | sarangani
# Processing Record 35 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 7 | robertsport
# Processing Record 37 of Set 7 | homer
# Processing Record 38 of Set 7 | beni mazar
# Processing Record 39 of Set 7 | anadyr
# Processing Record 40 of Set 7 | maturin
# Processing Record 41 of Set 7 | talnakh
# Processing Record 42 of Set 7 | vila velha
# Processing Record 43 of Set 7 | guanhaes
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | pochutla
# Processing Record 46 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 7 | fare
# Processing Record 48 of Set 7 | coquimbo
# Processing Record 49 of Set 7 | balkanabat
# Processing Record 50 of Set 7 | general teran
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | perth
# Processing Record 3 of Set 8 | vilhena
# Processing Record 4 of Set 8 | capaci
# Processing Record 5 of Set 8 | saint-philippe
# Processing Record 6 of Set 8 | borovoy
# Processing Record 7 of Set 8 | rongcheng
# Processing Record 8 of Set 8 | kapit
# Processing Record 9 of Set 8 | huambo
# Processing Record 10 of Set 8 | kenai
# Processing Record 11 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 8 | raton
# Processing Record 13 of Set 8 | bujaru
# Processing Record 14 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 8 | batagay-alyta
# Processing Record 16 of Set 8 | sola
# Processing Record 17 of Set 8 | kalmar
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | puerto escondido
# Processing Record 20 of Set 8 | saint-pierre
# Processing Record 21 of Set 8 | corning
# Processing Record 22 of Set 8 | kaoma
# Processing Record 23 of Set 8 | birin
# Processing Record 24 of Set 8 | ahipara
# Processing Record 25 of Set 8 | victoria
# Processing Record 26 of Set 8 | zeya
# Processing Record 27 of Set 8 | cam ranh
# Processing Record 28 of Set 8 | vaitape
# Processing Record 29 of Set 8 | dargaville
# Processing Record 30 of Set 8 | irtyshskiy
# Processing Record 31 of Set 8 | gravdal
# Processing Record 32 of Set 8 | stromness
# Processing Record 33 of Set 8 | verkhoyansk
# Processing Record 34 of Set 8 | dalmeny
# Processing Record 35 of Set 8 | leonidovo
# Processing Record 36 of Set 8 | taltal
# Processing Record 37 of Set 8 | arman
# Processing Record 38 of Set 8 | khuzdar
# Processing Record 39 of Set 8 | mesyagutovo
# Processing Record 40 of Set 8 | egvekinot
# Processing Record 41 of Set 8 | comodoro rivadavia
# Processing Record 42 of Set 8 | natal
# Processing Record 43 of Set 8 | suarez
# Processing Record 44 of Set 8 | karlskoga
# Processing Record 45 of Set 8 | maniitsoq
# Processing Record 46 of Set 8 | hun
# Processing Record 47 of Set 8 | mizdah
# Processing Record 48 of Set 8 | la uribe
# City not found. Skipping...
# Processing Record 49 of Set 8 | dublin
# Processing Record 50 of Set 8 | lichinga
# Processing Record 1 of Set 9 | soe
# Processing Record 2 of Set 9 | katangli
# Processing Record 3 of Set 9 | villa rica
# Processing Record 4 of Set 9 | edwardsville
# Processing Record 5 of Set 9 | asmara
# Processing Record 6 of Set 9 | ambilobe
# Processing Record 7 of Set 9 | bud
# Processing Record 8 of Set 9 | davila
# Processing Record 9 of Set 9 | coulommiers
# Processing Record 10 of Set 9 | lyngseidet
# Processing Record 11 of Set 9 | rovaniemi
# Processing Record 12 of Set 9 | riyadh
# Processing Record 13 of Set 9 | kiunga
# Processing Record 14 of Set 9 | ystad
# Processing Record 15 of Set 9 | san patricio
# Processing Record 16 of Set 9 | parabel
# Processing Record 17 of Set 9 | chernyakhovsk
# Processing Record 18 of Set 9 | wolmirstedt
# Processing Record 19 of Set 9 | sept-iles
# Processing Record 20 of Set 9 | alyangula
# Processing Record 21 of Set 9 | warri
# Processing Record 22 of Set 9 | bandarbeyla
# Processing Record 23 of Set 9 | valparaiso
# Processing Record 24 of Set 9 | saint george
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | dicabisagan
# Processing Record 27 of Set 9 | mattoon
# Processing Record 28 of Set 9 | hakodate
# Processing Record 29 of Set 9 | abulug
# Processing Record 30 of Set 9 | nanortalik
# Processing Record 31 of Set 9 | rundu
# Processing Record 32 of Set 9 | kuito
# Processing Record 33 of Set 9 | buin
# Processing Record 34 of Set 9 | namatanai
# Processing Record 35 of Set 9 | tarija
# Processing Record 36 of Set 9 | shiyan
# Processing Record 37 of Set 9 | ruteng
# Processing Record 38 of Set 9 | kalundborg
# Processing Record 39 of Set 9 | payo
# Processing Record 40 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 9 | jiangyou
# Processing Record 42 of Set 9 | rio gallegos
# Processing Record 43 of Set 9 | andenes
# Processing Record 44 of Set 9 | castlerea
# Processing Record 45 of Set 9 | mahon
# Processing Record 46 of Set 9 | port blair
# Processing Record 47 of Set 9 | kununurra
# Processing Record 48 of Set 9 | uyuni
# Processing Record 49 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 9 | dingle
# Processing Record 1 of Set 10 | nsanje
# Processing Record 2 of Set 10 | mananjary
# Processing Record 3 of Set 10 | umm lajj
# Processing Record 4 of Set 10 | mackenzie
# Processing Record 5 of Set 10 | khorixas
# Processing Record 6 of Set 10 | nanakuli
# Processing Record 7 of Set 10 | kodiak
# Processing Record 8 of Set 10 | new lenox
# Processing Record 9 of Set 10 | sukhumi
# Processing Record 10 of Set 10 | kendal
# Processing Record 11 of Set 10 | leningradskiy
# Processing Record 12 of Set 10 | pontalina
# Processing Record 13 of Set 10 | dalian
# Processing Record 14 of Set 10 | salisbury
# Processing Record 15 of Set 10 | hearst
# Processing Record 16 of Set 10 | praia da vitoria
# Processing Record 17 of Set 10 | homestead
# Processing Record 18 of Set 10 | middelfart
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | palencia
# Processing Record 21 of Set 10 | alice springs
# Processing Record 22 of Set 10 | murmashi
# Processing Record 23 of Set 10 | abu kamal
# Processing Record 24 of Set 10 | madimba
# Processing Record 25 of Set 10 | harkany
# Processing Record 26 of Set 10 | la orilla
# Processing Record 27 of Set 10 | mokhotlong
# Processing Record 28 of Set 10 | baruun-urt
# Processing Record 29 of Set 10 | dasoguz
# Processing Record 30 of Set 10 | neiafu
# Processing Record 31 of Set 10 | sao jose da coroa grande
# Processing Record 32 of Set 10 | waingapu
# Processing Record 33 of Set 10 | mwingi
# Processing Record 34 of Set 10 | poitiers
# Processing Record 35 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 10 | okhotsk
# Processing Record 37 of Set 10 | requena
# Processing Record 38 of Set 10 | grand-lahou
# Processing Record 39 of Set 10 | yerbogachen
# Processing Record 40 of Set 10 | nantucket
# Processing Record 41 of Set 10 | severo-kurilsk
# Processing Record 42 of Set 10 | hasaki
# Processing Record 43 of Set 10 | nichinan
# Processing Record 44 of Set 10 | general roca
# Processing Record 45 of Set 10 | taiobeiras
# Processing Record 46 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 10 | jish
# Processing Record 48 of Set 10 | hobyo
# Processing Record 49 of Set 10 | uppiliapuram
# City not found. Skipping...
# Processing Record 50 of Set 10 | khudumelapye
# Processing Record 1 of Set 11 | quatre cocos
# Processing Record 2 of Set 11 | parrita
# Processing Record 3 of Set 11 | luderitz
# Processing Record 4 of Set 11 | cabo san lucas
# Processing Record 5 of Set 11 | taquari
# Processing Record 6 of Set 11 | mercedes
# Processing Record 7 of Set 11 | sal rei
# Processing Record 8 of Set 11 | rawson
# Processing Record 9 of Set 11 | del rio
# Processing Record 10 of Set 11 | nouadhibou
# Processing Record 11 of Set 11 | laguna
# Processing Record 12 of Set 11 | macusani
# Processing Record 13 of Set 11 | adeje
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | sao sepe
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | tauramena
# Processing Record 18 of Set 11 | ormara
# Processing Record 19 of Set 11 | havre-saint-pierre
# Processing Record 20 of Set 11 | hrinova
# Processing Record 21 of Set 11 | dhadar
# Processing Record 22 of Set 11 | pitiquito
# Processing Record 23 of Set 11 | whitehorse
# Processing Record 24 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 11 | alofi
# Processing Record 26 of Set 11 | lebanon
# Processing Record 27 of Set 11 | terrace
# Processing Record 28 of Set 11 | yangliuqing
# Processing Record 29 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 11 | izhma
# Processing Record 31 of Set 11 | beidao
# Processing Record 32 of Set 11 | bayanday
# Processing Record 33 of Set 11 | quang ngai
# Processing Record 34 of Set 11 | stornoway
# Processing Record 35 of Set 11 | laurel
# Processing Record 36 of Set 11 | brigantine
# Processing Record 37 of Set 11 | yanam
# Processing Record 38 of Set 11 | oyem
# Processing Record 39 of Set 11 | granadilla de abona
# Processing Record 40 of Set 11 | nizhniy odes
# Processing Record 41 of Set 11 | hay river
# Processing Record 42 of Set 11 | okakarara
# Processing Record 43 of Set 11 | mmabatho
# Processing Record 44 of Set 11 | dunayivtsi
# City not found. Skipping...
# Processing Record 45 of Set 11 | samarai
# Processing Record 46 of Set 11 | mandal
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | grenfell
# Processing Record 49 of Set 11 | yatou
# Processing Record 50 of Set 11 | tambura
# Processing Record 1 of Set 12 | myskhako
# Processing Record 2 of Set 12 | olinda
# Processing Record 3 of Set 12 | detchino
# Processing Record 4 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 12 | lakes entrance
# Processing Record 6 of Set 12 | lebork
# Processing Record 7 of Set 12 | griffith
# Processing Record 8 of Set 12 | kloulklubed
# Processing Record 9 of Set 12 | alekseyevka
# Processing Record 10 of Set 12 | ocampo
# Processing Record 11 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 12 | antofagasta
# Processing Record 13 of Set 12 | choya
# Processing Record 14 of Set 12 | talara
# Processing Record 15 of Set 12 | boralday
# Processing Record 16 of Set 12 | sterling
# Processing Record 17 of Set 12 | navoi
# Processing Record 18 of Set 12 | honiara
# Processing Record 19 of Set 12 | skeldon
# Processing Record 20 of Set 12 | zheleznodorozhnyy
# Processing Record 21 of Set 12 | chulym
# Processing Record 22 of Set 12 | menongue
# Processing Record 23 of Set 12 | usinsk
# Processing Record 24 of Set 12 | kandi
# Processing Record 25 of Set 12 | odweyne
# Processing Record 26 of Set 12 | yefira
# City not found. Skipping...
# Processing Record 27 of Set 12 | petapa
# Processing Record 28 of Set 12 | fernandina beach
# Processing Record 29 of Set 12 | vyazniki
# Processing Record 30 of Set 12 | numan
# Processing Record 31 of Set 12 | mogochin
# City not found. Skipping...
# Processing Record 32 of Set 12 | sorland
# Processing Record 33 of Set 12 | monopoli
# Processing Record 34 of Set 12 | nizhniy tsasuchey
# Processing Record 35 of Set 12 | prince rupert
# Processing Record 36 of Set 12 | clonakilty
# Processing Record 37 of Set 12 | mao
# Processing Record 38 of Set 12 | asau
# Processing Record 39 of Set 12 | helong
# Processing Record 40 of Set 12 | teutonia
# Processing Record 41 of Set 12 | kharp
# Processing Record 42 of Set 12 | baykit
# Processing Record 43 of Set 12 | viedma
# Processing Record 44 of Set 12 | gambela
# Processing Record 45 of Set 12 | pimentel
# Processing Record 46 of Set 12 | kurtalan
# Processing Record 47 of Set 12 | kamaishi
# Processing Record 48 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 12 | cockburn town
# Processing Record 50 of Set 12 | abaete
# Processing Record 1 of Set 13 | maposeni
# Processing Record 2 of Set 13 | umarga
# Processing Record 3 of Set 13 | roald
# Processing Record 4 of Set 13 | pasni
# Processing Record 5 of Set 13 | kalavad
# Processing Record 6 of Set 13 | chiredzi
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | puerto penasco
# Processing Record 9 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 13 | sao paulo de olivenca
# Processing Record 11 of Set 13 | pandan
# Processing Record 12 of Set 13 | grand forks
# Processing Record 13 of Set 13 | talcahuano
# Processing Record 14 of Set 13 | ilebo
# Processing Record 15 of Set 13 | port augusta
# Processing Record 16 of Set 13 | mazara del vallo
# Processing Record 17 of Set 13 | kapuskasing
# Processing Record 18 of Set 13 | aguimes
# Processing Record 19 of Set 13 | oksfjord
# Processing Record 20 of Set 13 | zhangye
# Processing Record 21 of Set 13 | barcelos
# Processing Record 22 of Set 13 | poum
# Processing Record 23 of Set 13 | cacule
# Processing Record 24 of Set 13 | boa vista
# Processing Record 25 of Set 13 | puerto leguizamo
# Processing Record 26 of Set 13 | lincoln
# Processing Record 27 of Set 13 | grand gaube
# Processing Record 28 of Set 13 | nelson bay
# Processing Record 29 of Set 13 | lasa
# Processing Record 30 of Set 13 | esfarayen
# Processing Record 31 of Set 13 | ambon
# Processing Record 32 of Set 13 | tias
# Processing Record 33 of Set 13 | lima
# Processing Record 34 of Set 13 | lavrentiya
# Processing Record 35 of Set 13 | souillac
# Processing Record 36 of Set 13 | tabas
# Processing Record 37 of Set 13 | meadow lake
# Processing Record 38 of Set 13 | wageningen
# Processing Record 39 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 13 | moerai
# Processing Record 41 of Set 13 | am timan
# Processing Record 42 of Set 13 | paciran
# Processing Record 43 of Set 13 | carmen
# Processing Record 44 of Set 13 | ekhabi
# Processing Record 45 of Set 13 | russell
# Processing Record 46 of Set 13 | hastings
# Processing Record 47 of Set 13 | tessalit
# Processing Record 48 of Set 13 | boyuibe
# Processing Record 49 of Set 13 | alta gracia
# Processing Record 50 of Set 13 | blagoevgrad
# Processing Record 1 of Set 14 | visby
# Processing Record 2 of Set 14 | bulgan
# Processing Record 3 of Set 14 | elizabeth city
# Processing Record 4 of Set 14 | barra do bugres
# Processing Record 5 of Set 14 | coos bay
# Processing Record 6 of Set 14 | atar
# Processing Record 7 of Set 14 | mumford
# Processing Record 8 of Set 14 | port hawkesbury
# Processing Record 9 of Set 14 | koulikoro
# Processing Record 10 of Set 14 | kalianget
# Processing Record 11 of Set 14 | yagodnoye
# Processing Record 12 of Set 14 | calvinia
# Processing Record 13 of Set 14 | zaraza
# Processing Record 14 of Set 14 | faya
# Processing Record 15 of Set 14 | tukrah
# Processing Record 16 of Set 14 | beyneu
# Processing Record 17 of Set 14 | whitefish
# Processing Record 18 of Set 14 | saint-louis
# Processing Record 19 of Set 14 | sao felix do xingu
# Processing Record 20 of Set 14 | flinders
# Processing Record 21 of Set 14 | amazar
# Processing Record 22 of Set 14 | khatima
# Processing Record 23 of Set 14 | buraydah
# Processing Record 24 of Set 14 | puerto cabezas
# Processing Record 25 of Set 14 | mugur-aksy
# Processing Record 26 of Set 14 | aksu
# Processing Record 27 of Set 14 | noumea
# Processing Record 28 of Set 14 | porto novo
# Processing Record 29 of Set 14 | karia
# Processing Record 30 of Set 14 | launceston
# Processing Record 31 of Set 14 | rock sound
# Processing Record 32 of Set 14 | kirkuk
# Processing Record 33 of Set 14 | altamont
# Processing Record 34 of Set 14 | togul
# Processing Record 35 of Set 14 | iskateley
# Processing Record 36 of Set 14 | vila franca do campo
# Processing Record 37 of Set 14 | helena
# Processing Record 38 of Set 14 | mudbidri
# Processing Record 39 of Set 14 | verkhnyaya inta
# Processing Record 40 of Set 14 | igarka
# Processing Record 41 of Set 14 | sangar
# Processing Record 42 of Set 14 | tevriz
# Processing Record 43 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 44 of Set 14 | anloga
# Processing Record 45 of Set 14 | mega
# Processing Record 46 of Set 14 | kupang
# Processing Record 47 of Set 14 | muravlenko
# Processing Record 48 of Set 14 | broome
# Processing Record 49 of Set 14 | santa lucia
# Processing Record 50 of Set 14 | iwaki
# Processing Record 1 of Set 15 | canton
# Processing Record 2 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 15 | aitape
# Processing Record 5 of Set 15 | ulladulla
# Processing Record 6 of Set 15 | abu samrah
# Processing Record 7 of Set 15 | kpalime
# Processing Record 8 of Set 15 | khromtau
# Processing Record 9 of Set 15 | hornepayne
# Processing Record 10 of Set 15 | pergamino
# Processing Record 11 of Set 15 | miles city
# Processing Record 12 of Set 15 | rio grande
# Processing Record 13 of Set 15 | sabla
# Processing Record 14 of Set 15 | ojinaga
# Processing Record 15 of Set 15 | pandelys
# City not found. Skipping...
# Processing Record 16 of Set 15 | rocky mountain house
# Processing Record 17 of Set 15 | vostok
# Processing Record 18 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 15 | san carlos de bariloche
# Processing Record 20 of Set 15 | ankazoabo
# Processing Record 21 of Set 15 | dongning
# Processing Record 22 of Set 15 | naze
# Processing Record 23 of Set 15 | el paso
# Processing Record 24 of Set 15 | hervey bay
# Processing Record 25 of Set 15 | shenavan
# Processing Record 26 of Set 15 | olafsvik
# Processing Record 27 of Set 15 | temir
# Processing Record 28 of Set 15 | high level
# Processing Record 29 of Set 15 | matara
# Processing Record 30 of Set 15 | arrifes
# Processing Record 31 of Set 15 | mascote
# Processing Record 32 of Set 15 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 33 of Set 15 | afzalgarh
# Processing Record 34 of Set 15 | thung song
# Processing Record 35 of Set 15 | moree
# Processing Record 36 of Set 15 | proddatur
# Processing Record 37 of Set 15 | berlevag
# Processing Record 38 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 15 | karlstad
# Processing Record 40 of Set 15 | kemin
# Processing Record 41 of Set 15 | kaili
# Processing Record 42 of Set 15 | truro
# Processing Record 43 of Set 15 | berbera
# Processing Record 44 of Set 15 | chavakkad
# Processing Record 45 of Set 15 | khani
# Processing Record 46 of Set 15 | benguela
# Processing Record 47 of Set 15 | atagay
# Processing Record 48 of Set 15 | ponerihouen
# Processing Record 49 of Set 15 | esso
# Processing Record 50 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 1 of Set 16 | santa fe
# Processing Record 2 of Set 16 | bambanglipuro
# Processing Record 3 of Set 16 | ornskoldsvik
# Processing Record 4 of Set 16 | axim
# Processing Record 5 of Set 16 | caceres
# Processing Record 6 of Set 16 | biltine
# Processing Record 7 of Set 16 | korla
# Processing Record 8 of Set 16 | acajutla
# Processing Record 9 of Set 16 | dzhebariki-khaya
# Processing Record 10 of Set 16 | salamiyah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tuatapere -46.1333  167.6833     59.83        96          28
# 1     Grindavik  63.8424  -22.4338     32.47        69          75
# 2         Vitim  59.4511  112.5578     -9.09        98         100
# 3     Jaisalmer  26.9147   70.9181     67.73        20           0
# 4         Kapaa  22.0752 -159.3190     67.98        97          40
# 5         Anito  12.4497  125.2886     77.83        81          97
# 6        Albany  42.6001  -73.9662     43.09        81          97
# 7      Ust-Maya  60.4167  134.5333    -25.98       100          97
# 8  Ponta Do Sol  32.6667  -17.1000     71.71        79         100
# 9       Mataura -46.1927  168.8643     59.49        98          56
#
#    Wind Speed Country                 Date Current Description
# 0        1.57      NZ  2022-02-10 15:38:58    scattered clouds
# 1       17.27      IS  2022-02-10 15:33:46       broken clouds
# 2        4.70      RU  2022-02-10 15:38:58     overcast clouds
# 3        3.11      IN  2022-02-10 15:38:59           clear sky
# 4        6.91      US  2022-02-10 15:29:04    scattered clouds
# 5       12.12      PH  2022-02-10 15:38:59     overcast clouds
# 6        1.99      US  2022-02-10 15:37:00     overcast clouds
# 7        2.15      RU  2022-02-10 15:38:59     overcast clouds
# 8        6.08      PT  2022-02-10 15:32:34     overcast clouds
# 9        1.74      NZ  2022-02-10 15:35:43       broken clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Tuatapere      NZ -46.1333  167.6833     59.83        96
# 1           Grindavik      IS  63.8424  -22.4338     32.47        69
# 2               Vitim      RU  59.4511  112.5578     -9.09        98
# 3           Jaisalmer      IN  26.9147   70.9181     67.73        20
# 4               Kapaa      US  22.0752 -159.3190     67.98        97
# ..                ...     ...      ...       ...       ...       ...
# 698           Biltine      TD  14.5333   20.9167     83.28         7
# 699             Korla      CN  41.7597   86.1469     28.69        47
# 700          Acajutla      SV  13.5928  -89.8275     83.80        42
# 701  Dzhebariki-Khaya      RU  62.2167  135.8000    -36.00       100
# 702         Salamiyah      SY  35.0113   37.0532     45.79        75
#
#      Cloudiness  Wind Speed Current Description
# 0            28        1.57    scattered clouds
# 1            75       17.27       broken clouds
# 2           100        4.70     overcast clouds
# 3             0        3.11           clear sky
# 4            40        6.91    scattered clouds
# ..          ...         ...                 ...
# 698           0       10.38           clear sky
# 699          91        2.06     overcast clouds
# 700           1        0.92           clear sky
# 701          89        0.60     overcast clouds
# 702         100       11.59     overcast clouds
#
# [703 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
